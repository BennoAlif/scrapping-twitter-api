# %%
from pathlib import Path
import pandas as pd

path = r'./csv/'  # or unix / linux / mac path

# Get the files from the path provided in the OP
files = Path(path).glob('*.csv')  # .rglob to get subdirectories

df = pd.concat((pd.read_csv(f, index_col=0, encoding="ISO-8859-1") for f in files), ignore_index=True)

# %%
df.head()
# Out:
#       textID                                         tweet_text Unnamed: 3  \
# 0  1.576E+18      RT @catturd2: Iâm so sick of this bullshit.        NaN
# 1  1.576E+18  RT @mae_rusia: ð¬ VladÃ­mir Putin: A los ang...        NaN
# 2  1.576E+18  RT @mhmck: It's 1 a.m. in Ukraine and there's ...        NaN
# 3  1.576E+18  And your skin color would still be same if you...        NaN
# 4  1.576E+18  RT @Jakob_Reimann: Die #Ostsee ist eines der i...        NaN
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN

# %%
# Hapus kolom
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df
# Out:
#                      textID                                         tweet_text
# 0                 1.576E+18      RT @catturd2: Iâm so sick of this bullshit.
# 1                 1.576E+18  RT @mae_rusia: ð¬ VladÃ­mir Putin: A los ang...
# 2                 1.576E+18  RT @mhmck: It's 1 a.m. in Ukraine and there's ...
# 3                 1.576E+18  And your skin color would still be same if you...
# 4                 1.576E+18  RT @Jakob_Reimann: Die #Ostsee ist eines der i...
# ...                     ...                                                ...
# 124808  1576014006078558213  RT @MayraFlores2022: Congress just voted to se...
# 124809  1576014006254374912  RT @HelenaVillarRT: Biden sobre el NordStream:...
# 124810  1576014006346997760  RT @BillKristol: CPAC all in for Putin--"the a...
# 124811  1576014006648594432  RT @motorwars: à¸à¸à¸.Zelenskyy à¹à¸à¸¥à¸...
# 124812  1576014007005515778  RT @BorisJohnson: Vladimir Putin your speech i...
#
# [124813 rows x 2 columns]

# %%
df.to_csv("./result/result.csv")
